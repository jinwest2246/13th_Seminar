# %% [markdown]
# # 시리즈 만들기

# %%
import pandas as pd
s = pd.Series(["banana",42])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s = pd.Series(["Wes Mckinney", "Creator of Pandas"])
print(s)
# Out:
# 0         Wes Mckinney
# 1    Creator of Pandas
# dtype: object

# %%
s = pd.Series(["Wes Mckinney", "Creator of Pandas"], index=["Person","Who"])
print(s)
# Out:
# Person         Wes Mckinney
# Who       Creator of Pandas
# dtype: object

# %% [markdown]
# # 데이터프레임 만들기

# %%
scientists = pd.DataFrame({
    'Name':["Rosaline","William"],
    'Occupation':["Chemist","Statistician"],
    'Born':["1920-07-25","1876-06-13"],
    'Died':["1958-04-16","1937-10-16"],
    'Age':[37,61]})
print(scientists)
# Out:
#        Name    Occupation        Born        Died  Age
# 0  Rosaline       Chemist  1920-07-25  1958-04-16   37
# 1   William  Statistician  1876-06-13  1937-10-16   61

# %%
#인덱스 이름 설정
scientists = pd.DataFrame(
    data={'Name':["Rosaline","William"],
          'Occupation':["Chemist","Statistician"],
          'Born':["1920-07-25","1876-06-13"],
          'Died':["1958-04-16","1937-10-16"],
          'Age':[37,61]},
    index=["Rosaline","William"],
    columns=["Occupation","Born","Age","Died"])
print(scientists)
# Out:
#             Occupation        Born  Age        Died
# Rosaline       Chemist  1920-07-25   37  1958-04-16
# William   Statistician  1876-06-13   61  1937-10-16

# %%
from collections import OrderedDict

scientist = pd.DataFrame(OrderedDict([
    ('Name',["Rosaline","William"]),
    ('Occupation',["Chemist","Statistician"]),
    ('Born',["1920-07-25","1876-06-13"]),
    ('Died',["1958-04-16","1937-10-16"]),
    ('Age',[37,61])
]))
print(scientists)
# Out:
#             Occupation        Born  Age        Died
# Rosaline       Chemist  1920-07-25   37  1958-04-16
# William   Statistician  1876-06-13   61  1937-10-16

# %% [markdown]
# # 데이터프레임에서 시리즈 선택하기

# %%
scientists = pd.DataFrame(
    data={'Name':["Rosaline","William"],
          'Occupation':["Chemist","Statistician"],
          'Born':["1920-07-25","1876-06-13"],
          'Died':["1958-04-16","1937-10-16"],
          'Age':[37,61]},
    index=["Rosaline","William"],
    columns=["Occupation","Born","Age","Died"])

# %%
first_row = scientists.loc["William"]
print(type(first_row))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(first_row)
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Age                     61
# Died            1937-10-16
# Name: William, dtype: object

# %% [markdown]
# # index, values, keys 사용하기

# %%
print(first_row.index)  #index속성
# Out:
# Index(['Occupation', 'Born', 'Age', 'Died'], dtype='object')

# %%
print(first_row.values)  #values속성
# Out:
# ['Statistician' '1876-06-13' np.int64(61) '1937-10-16']

# %%
print(first_row.keys())  #keys메서드
# Out:
# Index(['Occupation', 'Born', 'Age', 'Died'], dtype='object')

# %%
print(first_row.index[0])
# Out:
# Occupation

# %%
print(first_row.keys()[0])
# Out:
# Occupation

# %% [markdown]
# # 시리즈의 mean, min, max, std 메서드 사용하기

# %%
ages = scientists['Age']
print(ages)
# Out:
# Rosaline    37
# William     61
# Name: Age, dtype: int64

# %%
print(ages.mean())  #평균
print(ages.min())  #최소값
print(ages.max())  #최대값
print(ages.std())  #표준편차
# Out:
# 49.0
# 37
# 61
# 16.97056274847714

# %% [markdown]
# # 시리즈와 불린 추출 사용하기

# %%
scientists = pd.read_csv("C:/Users/user/OneDrive/Desktop/쿠글/doit_pandas-master/data/scientists.csv")

# %%
ages = scientists['Age']
print(ages.max())
print(ages.mean())
# Out:
# 90
# 59.125

# %%
print(ages[ages>ages.mean()])
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
print(ages>ages.mean())
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
print(type(ages>ages.mean()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
manual_bool_values = [True,True,False,False,True,True,False,True,]
print(ages[manual_bool_values])
# Out:
# 0    37
# 1    61
# 4    56
# 5    45
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# # 시리즈와 브로드캐스팅

# %%
print(ages+ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages*ages)
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
print(ages+100)
# Out:
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64

# %%
print(ages*2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(pd.Series([1,100]))
print(ages+pd.Series([1,100]))  #개수가 다른 시리즈끼리 더하면 결측값이 됨.
# Out:
# 0      1
# 1    100
# dtype: int64
# 0     38.0
# 1    161.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# dtype: float64

# %%
rev_ages = ages.sort_index(ascending=False)  #인덱스 역순으로 데이터 정렬
print(rev_ages)
# Out:
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64

# %%
print(ages*2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages+rev_ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %% [markdown]
# # 데이터프레임과 불린 추출

# %%
print(scientists[scientists["Age"] > scientists["Age"].mean()])
# Out:
#                    Name        Born        Died  Age     Occupation  \
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician
#
#      born_dt    died_dt age_days_dt
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12        NaT         NaT
# 3 1867-11-07        NaT         NaT
# 7 1777-04-30        NaT         NaT

# %%
Print(scientists.loc[[True, True, False, True]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 Print(scientists.loc[[True, True, False, True]])
#
# NameError: name 'Print' is not defined

# %% [markdown]
# # 데이터프레임과 브로드캐스팅

# %%
print(scientists * 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 print(scientists * 2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7935, in DataFrame._arith_method(self, other, op)
#    7932 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7934 with np.errstate(all="ignore"):
# ...

# %% [markdown]
# # 열의 자료형 바꾸기와 새로운 열 추가하기

# %%
#자료형 확인
print(scientist['Born'].dtype)
print(scientist['Died'].dtype)
# Out:
# object
# object

# %%
born_datetime = pd.to_datetime(scientists['Born'],format='%Y-%m-%d')
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
died_datetime = pd.to_datetime(scientist['Died'],format="%Y-%m-%d")
print(died_datetime)
# Out:
# 0   1958-04-16
# 1   1937-10-16
# Name: Died, dtype: datetime64[ns]

# %%
scientists['born_dt'], scientists['died_dt'] = (born_datetime,died_datetime)
print(scientists.head())
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2        NaT
# 3        NaT
# 4        NaT

# %%
print(scientists.shape)
# Out:
# (8, 7)

# %%
scientists['age_days_dt']=(scientists['died_dt']-scientists['born_dt'])
print(scientists)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12        NaT         NaT
# 3 1867-11-07        NaT         NaT
# 4 1907-05-27        NaT         NaT
# 5 1813-03-15        NaT         NaT
# 6 1912-06-23        NaT         NaT
# ...

# %% [markdown]
# # 시리즈, 데이터프레임의 데이터 섞어보기

# %%
print(scientists['Age'])
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
import random

random.seed(42)
random.shuffle(scientists['Age'])
print(scientists['Age'])
# Out:
# 0    61
# 1    41
# 2    66
# 3    56
# 4    37
# 5    45
# 6    77
# 7    90
# Name: Age, dtype: int64
# C:\Users\user\anaconda3\Lib\random.py:361: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]
# C:\Users\user\anaconda3\Lib\random.py:361: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]
# C:\Users\user\anaconda3\Lib\random.py:361: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# # 데이터프레임의 열 삭제하기

# %%
print(scientists.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt'],
#       dtype='object')

# %%
scientists_dropped = scientist.drop(['Age'],axis=1)
print(scientists_dropped.columns)
# Out:
# Index(['Name', 'Occupation', 'Born', 'Died'], dtype='object')

# %% [markdown]
# # 피클 형식으로 저장하기

# %%
names = scientists['Name']
names.to_pickle("C:/Users/user/OneDrive/Desktop/쿠글/doit_pandas-master/data/scientists.pickle")

# %%
scientists.to_pickle("C:/Users/user/OneDrive/Desktop/쿠글/doit_pandas-master/data/scientists.pickle")

# %%
scientists_names_from_pickle = pd.read_pickle("C:/Users/user/OneDrive/Desktop/쿠글/doit_pandas-master/data/scientists.pickle")
print(scientists_names_from_pickle)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   41        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   66               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   56             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   37           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   77  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   90       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12        NaT         NaT
# 3 1867-11-07        NaT         NaT
# 4 1907-05-27        NaT         NaT
# 5 1813-03-15        NaT         NaT
# 6 1912-06-23        NaT         NaT
# ...

# %%
scientists_from_pickle = pd.read_pickle("C:/Users/user/OneDrive/Desktop/쿠글/doit_pandas-master/data/scientists.pickle")
print(scientists_names_from_pickle)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   41        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   66               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   56             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   37           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   77  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   90       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12        NaT         NaT
# 3 1867-11-07        NaT         NaT
# 4 1907-05-27        NaT         NaT
# 5 1813-03-15        NaT         NaT
# 6 1912-06-23        NaT         NaT
# ...

# %% [markdown]
# # CSV 불러오기

# %%
#csv:데이터가 콤마로 구분 / tsv:데이터가 탭으로 구분
names.to_csv("C:/Users/user/OneDrive/Desktop/쿠글/doit_pandas-master/data/scientists_names_series.csv")
scientists.to_csv("C:/Users/user/OneDrive/Desktop/쿠글/doit_pandas-master/data/scientists_df.tsv",sep='t')
